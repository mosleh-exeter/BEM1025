# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mosleh-exeter/BEM1025/blob/main/ExamPrep/Exam2/Exam2_Prep2-solutions.ipynb)

# %%
# we import the library pandas and give it the "pd" kickname
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # **For all questions YOU HAVE TO WRITE SOME CORRECT  PYTHON CODE! simply giving the final answer is not enough!**

# %% [markdown]
# ### You need to download this file as ipynb, zip (compress it) it, and upload as a zip file to BART.
# <img width="800" height="400" src="https://github.com/mosleh-exeter/BEM1025/raw/main/images/UploadBart.png">
#
# ### For all questions YOU HAVE TO WRITE SOME CORRECT PYTHON CODE! simply giving the final answer is not enough!
# ### You can provide brief description if you think that helps understanding of your code.
# ### You need to make your code adaptable and scalable; and avoid manual entry of data as much as it is possible.

# %% [markdown]
# ### You will work on the following dataframe for this assignment

# %%
# similar to reading data from csv file, we can read data from excel sheets, we need to specify which column we need to read data from
# this data is a sample from comercial software Tableau
df_=pd.read_excel('https://www.dropbox.com/s/fxl8z39kpbhmdhn/Superstore.xls?dl=1')
df=pd.pivot_table(df_,index=['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode','Customer ID', 
                         'Customer Name', 'Segment', 'Country', 'City', 'State','Postal Code', 'Region',
                         'Product ID', 'Category', 'Sub-Category','Product Name'],columns=['variable'],values= 'value')
df.reset_index(inplace=True)
df.head()
# Out:
# variable  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0              1  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 1              2  CA-2013-152156 2013-11-09 2013-11-12    Second Class
# 2              3  CA-2013-138688 2013-06-13 2013-06-17    Second Class
# 3              4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 4              5  US-2012-108966 2012-10-11 2012-10-18  Standard Class
#
# variable Customer ID    Customer Name    Segment        Country  \
# 0           CG-12520      Claire Gute   Consumer  United States
# 1           CG-12520      Claire Gute   Consumer  United States
# 2           DV-13045  Darrin Van Huff  Corporate  United States
# 3           SO-20335   Sean O'Donnell   Consumer  United States
# 4           SO-20335   Sean O'Donnell   Consumer  United States
#
# variable             City  ... Postal Code  Region       Product ID  \
# 0               Henderson  ...       42420   South  FUR-BO-10001798
# 1               Henderson  ...       42420   South  FUR-CH-10000454
# 2             Los Angeles  ...       90036    West  OFF-LA-10000240
# 3         Fort Lauderdale  ...       33311   South  FUR-TA-10000577
# 4         Fort Lauderdale  ...       33311   South  OFF-ST-10000760
#
# variable         Category Sub-Category  \
# 0               Furniture    Bookcases
# 1               Furniture       Chairs
# 2         Office Supplies       Labels
# 3               Furniture       Tables
# 4         Office Supplies      Storage
#
# variable                                       Product Name Discount  \
# 0                         Bush Somerset Collection Bookcase     0.00
# 1         Hon Deluxe Fabric Upholstered Stacking Chairs,...     0.00
# 2         Self-Adhesive Address Labels for Typewriters b...     0.00
# 3             Bretford CR4500 Series Slim Rectangular Table     0.45
# 4                            Eldon Fold 'N Roll Cart System     0.20
#
# variable    Profit  Quantity     Sales
# 0          41.9136       2.0  261.9600
# 1         219.5820       3.0  731.9400
# 2           6.8714       2.0   14.6200
# 3        -383.0310       5.0  957.5775
# 4           2.5164       2.0   22.3680
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Discount       9994 non-null   float64
#  18  Profit         9994 non-null   float64
#  19  Quantity       9994 non-null   float64
#  20  Sales          9994 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Assignment 1
# ### Find orders with sales value of 300 or more, discount above .01 and containing word 'Chair' or 'Table' or 'Desk' in their product names.
#
# ### **OUTCOME:** Provide the **head** and **shape** of the outcome dataframe

# %%
#'\' is used to break lines, so you can write an instruction in multiple lines
filter_1=(df['Sales']>=300) & \
        (df['Discount']>=.01) & \
        ((df['Product Name'].str.contains('Chair'))|df['Product Name'].str.contains('Table')|df['Product Name'].str.contains('Desk'))

# %%
df[filter_1].head()
# Out:
# variable  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3              4  US-2012-108966 2012-10-11 2012-10-18  Standard Class
# 10            11  CA-2011-115812 2011-06-09 2011-06-14  Standard Class
# 57            58  CA-2013-111682 2013-06-18 2013-06-19     First Class
# 72            73  US-2012-134026 2012-04-26 2012-05-02  Standard Class
# 124          125  US-2011-152030 2011-12-26 2011-12-28    Second Class
#
# variable Customer ID    Customer Name      Segment        Country  \
# 3           SO-20335   Sean O'Donnell     Consumer  United States
# 10          BH-11710  Brosina Hoffman     Consumer  United States
# 57          TB-21055  Ted Butterfield     Consumer  United States
# 72          JE-15745       Joel Eaton     Consumer  United States
# 124         AD-10180   Alan Dominguez  Home Office  United States
#
# variable             City  ... Postal Code   Region       Product ID  \
# 3         Fort Lauderdale  ...       33311    South  FUR-TA-10000577
# 10            Los Angeles  ...       90032     West  FUR-TA-10001539
# 57                   Troy  ...       12180     East  FUR-CH-10003968
# 72                Memphis  ...       38109    South  FUR-CH-10000513
# 124               Houston  ...       77041  Central  FUR-CH-10004063
#
# variable   Category Sub-Category  \
# 3         Furniture       Tables
# 10        Furniture       Tables
# 57        Furniture       Chairs
# 72        Furniture       Chairs
# 124       Furniture       Chairs
#
# variable                                   Product Name Discount    Profit  \
# 3         Bretford CR4500 Series Slim Rectangular Table     0.45 -383.0310
# 10             Chromcraft Rectangular Conference Tables     0.20   85.3092
# 57                             Novimex Turbo Task Chair     0.10    7.0980
# 72                    High-Back Leather Manager's Chair     0.20 -114.3912
# 124             Global Deluxe High-Back Manager's Chair     0.30   -8.5794
#
# variable  Quantity      Sales
# 3              5.0   957.5775
# 10             9.0  1706.1840
# 57             5.0   319.4100
# 72             8.0   831.9360
# 124            3.0   600.5580
#
# [5 rows x 21 columns]

# %%
df[filter_1].shape
# Out:
# (401, 21)

# %% [markdown]
# ## Assignment 2
# ### Find the 5 top cities with lowest average sales
#
# ### **OUTCOME:** Provide the list of the 5 cities (and their corresponding state and countries)
# ### Tip: you need to find the average price for all given cities (and their corresponding state and countries) and then sort them by sales

# %%
df.groupby(['City','State','Country'])[['Sales']].mean()\
    .reset_index()\
    .sort_values(by='Sales',ascending=True).head(5)
# Out:
# variable          City    State        Country  Sales
# 1              Abilene    Texas  United States  1.392
# 162             Elyria     Ohio  United States  1.824
# 257            Jupiter  Florida  United States  2.064
# 425          Pensacola  Florida  United States  2.214
# 408       Ormond Beach  Florida  United States  2.808

# %% [markdown]
# ## Assignment 3
# ### Transform the dataframe into a long dataframe to include a column representing geography (Country, State, and City) column representing its value
#
# ### **OUTCOME:** Provide the **head** and **shape** of the outcome

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object', name='variable')

# %%
df_melt=df.melt(id_vars=['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
       'Customer ID', 'Customer Name', 'Segment', 
       'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
       'Product Name', 'Discount', 'Profit', 'Quantity', 'Sales'],
        value_vars=['Country', 'City', 'State'])
df_melt.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-11-09 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688 2013-06-13 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-10-11 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment  Postal Code Region       Product ID  \
# 0      Claire Gute   Consumer        42420  South  FUR-BO-10001798
# 1      Claire Gute   Consumer        42420  South  FUR-CH-10000454
# 2  Darrin Van Huff  Corporate        90036   West  OFF-LA-10000240
# 3   Sean O'Donnell   Consumer        33311  South  FUR-TA-10000577
# 4   Sean O'Donnell   Consumer        33311  South  OFF-ST-10000760
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name  Discount    Profit  \
# 0                  Bush Somerset Collection Bookcase      0.00   41.9136
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...      0.00  219.5820
# 2  Self-Adhesive Address Labels for Typewriters b...      0.00    6.8714
# 3      Bretford CR4500 Series Slim Rectangular Table      0.45 -383.0310
# 4                     Eldon Fold 'N Roll Cart System      0.20    2.5164
#
#    Quantity     Sales variable          value
# 0       2.0  261.9600  Country  United States
# 1       3.0  731.9400  Country  United States
# 2       2.0   14.6200  Country  United States
# 3       5.0  957.5775  Country  United States
# 4       2.0   22.3680  Country  United States

# %%
df_melt.shape
# Out:
# (29982, 20)

# %% [markdown]
# ## Assignment 4
# ### Plot the relationship between year the order was made and the average Proft for various product categories
#
# ### **OUTCOME:** Create a plot where x represents year the order was made, y represents average profit, and lines with different colors represent product category
#
# ### Tip: You need to group and average by year (use pd.Grouper and Groupby) and then plot using seaborn

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Grouper.html

# %%
df['date_formatted']=pd.to_datetime(df['Order Date'])

# %%
df_year=df.groupby(['Category',pd.Grouper(key='date_formatted',freq='1y')]).mean().reset_index()
sns.lineplot(data = df_year,x="date_formatted", y="Profit",hue='Category')
# Out:
# <AxesSubplot:xlabel='date_formatted', ylabel='Profit'>

# %% [markdown]
# ## Assignment 5
# ### For Orders less than 1000 in sales, Plot the distribution for Discount for various Regions and product Category
#
# ### **OUTCOME:** Create a facet plot where x represents 'discount', y represents 'frequency', color represents 'Category', columns represent 'Region'
#
# ### Tip: you need to combine FacetGrid with sns.histplot

# %%
facet = sns.FacetGrid(df[(df['Sales']<1000)], col='Region', hue='Category')
facet = facet.map(sns.histplot,'Discount')
facet = facet.add_legend()
