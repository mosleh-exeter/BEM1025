# %%
import pandas as pd

# %% [markdown]
# #### You can use the follow permanent links to github to read these datasets or download them to your computer

# %% [markdown]
# All datasets are from https://www.kaggle.com/rtatman/fun-beginner-friendly-datasets

# %% [markdown]
# Animal Bites
# Data on over 9,000 bites, including rabies tests
#
# https://www.kaggle.com/rtatman/animal-bites

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/mosleh-exeter/BEM1025/main/Fun%2C%20beginner-friendly%20datasets/Health_AnimalBites.csv')
df1.head()
# Out:
#              bite_date SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0  1985-05-05 00:00:00           DOG         NaN       FEMALE  LIG. BROWN
# 1  1986-02-12 00:00:00           DOG         NaN      UNKNOWN   BRO & BLA
# 2  1987-05-07 00:00:00           DOG         NaN      UNKNOWN         NaN
# 3  1988-10-02 00:00:00           DOG         NaN         MALE   BLA & BRO
# 4  1989-08-29 00:00:00           DOG         NaN       FEMALE     BLK-WHT
#
#    vaccination_yrs     vaccination_date victim_zip AdvIssuedYNDesc  \
# 0              1.0  1985-06-20 00:00:00      40229              NO
# 1              NaN                  NaN      40218              NO
# 2              NaN                  NaN      40219              NO
# 3              NaN                  NaN        NaN              NO
# 4              NaN                  NaN        NaN              NO
#
#   WhereBittenIDDesc      quarantine_date DispositionIDDesc head_sent_date  \
# ...

# %% [markdown]
# 80 Cereals
# Nutrition data on 80 cereal products
# https://www.kaggle.com/crawford/80-cereals

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/mosleh-exeter/BEM1025/main/Fun%2C%20beginner-friendly%20datasets/cereal.csv')
df2.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# Museums, Aquariums, and Zoos
# Name, location, and revenue for every museum in the United States
# https://www.kaggle.com/imls/museum-directory

# %%
df3=pd.read_csv('https://raw.githubusercontent.com/mosleh-exeter/BEM1025/main/Fun%2C%20beginner-friendly%20datasets/museums.csv')
df3.head()
# Out:
# /Users/mm1049/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (9,14,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Museum ID                                        Museum Name  \
# 0  8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1  8400200117                            ALASKA BOTANICAL GARDEN
# 2  8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3  8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4  8400200027                             ALASKA HERITAGE MUSEUM
#
#                                           Legal Name Alternate Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM            NaN
# 1                        ALASKA BOTANICAL GARDEN INC            NaN
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...            NaN
# ...

# %% [markdown]
# Nutrition facts for Starbucks Menu
# Nutrition information for Starbucks menu items, including food and drinks
#
# https://www.kaggle.com/starbucks/starbucks-menu

# %%
df3=pd.read_csv('https://raw.githubusercontent.com/mosleh-exeter/BEM1025/main/Fun%2C%20beginner-friendly%20datasets/starbucks-menu-nutrition-drinks.csv')
df3.head()
# Out:
#                                           Unnamed: 0 Calories Fat (g)  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                   Ombré Pink Drink        -       -
# 2                                         Pink Drink        -       -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
#
#   Carb. (g) Fiber (g) Protein Sodium
# 0        11         0       0     10
# 1         -         -       -      -
# 2         -         -       -      -
# 3        18         1       0     10
# 4        14         1       0     10
