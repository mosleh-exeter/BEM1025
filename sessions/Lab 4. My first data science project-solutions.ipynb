# %%
# we import the library pandas and give it the "pd" nickname
import pandas as pd
import numpy as np

# %% [markdown]
# # **For all questions YOU HAVE TO WRITE SOME CORRECT  PYTHON CODE! simply giving the final answer is not enough!**
#
# # You will receive credit for the Python code you will provide, you may also need to include some description for your answer particularly if you can't generate the correct outcome using the python code

# %% [markdown]
# ### Assignment 4.1
# #### (a) Create two variables called A1 and A2 in Python and assign them values of 5 and 9.
# #### (b) Create variable C which holds the value of A1 divided by A2 and variable D that holds their multiplication.

# %% [markdown]
# #### Hint: You can do this using basic Python functionality without operations from Pandas

# %% [markdown]
# ## (a)

# %%
A1=5
A2=9

# %% [markdown]
# ## (b)

# %%
C=A1/A2
D=A1*A2
print(C,D)
# Out:
# 0.5555555555555556 45

# %% [markdown]
# ### You will work on the following dataframe for the rest of assignments
# #### This dataset contains a subset of the fuel economy data that the EPA makes available on http://fueleconomy.gov. It contains only car models which had a new release every year between 1999 and 2008 - this was used as a proxy for the popularity of the car.:
#
# manufacturer: manufacturer name;
#
# model: model name;
#
# displ: engine size in litres;
#
# year: year of manufacture;
#
# cyl: number of cylinders;
#
# trans: type of transmission;
#
# drv: the type of drive train where f = front-wheel drive, r = rear wheel drive, 4 = 4wd;
#
# cty: city miles per gallon;
#
# hwy: highway miles per gallon;
#
# fl:fuel type;
#
# class: "type" of car e.g. compact etc

# %%
df=pd.read_csv('https://www.dropbox.com/s/rx9ondhbqvd9zcm/mpg.csv?dl=1')
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %% [markdown]
# ### Assignment 4.2
# #### (a) Provide the list of column names, and number of rows in the dataframe
# #### (b) Extract the columns "manufacturer", "model", and "year" (the outcome should have three columns not seperated single columns)
# #### (c) Extract rows number 10, 20, 30, 35
# #### (d) Extract columns "manufacturer", "year" and "class" for rows 100 and 200
# #### (e) Provide the list of unique manufacturer (you need to remove duplicated manufacturers), Hint: you can consult pandas document: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.unique.html

# %% [markdown]
# ## (a)

# %%
print(df.columns)
print(df.shape[0])
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')
# 234

# %% [markdown]
# ## (b)

# %%
df[['manufacturer','model','year']]
# Out:
#     manufacturer               model  year
# 0           audi                  a4  1999
# 1           audi                  a4  1999
# 2           audi                  a4  2008
# 3           audi                  a4  2008
# 4           audi                  a4  1999
# 5           audi                  a4  1999
# 6           audi                  a4  2008
# 7           audi          a4 quattro  1999
# 8           audi          a4 quattro  1999
# 9           audi          a4 quattro  2008
# 10          audi          a4 quattro  2008
# 11          audi          a4 quattro  1999
# 12          audi          a4 quattro  1999
# 13          audi          a4 quattro  2008
# 14          audi          a4 quattro  2008
# 15          audi          a6 quattro  1999
# 16          audi          a6 quattro  2008
# 17          audi          a6 quattro  2008
# 18     chevrolet  c1500 suburban 2wd  2008
# 19     chevrolet  c1500 suburban 2wd  2008
# 20     chevrolet  c1500 suburban 2wd  2008
# 21     chevrolet  c1500 suburban 2wd  1999
# 22     chevrolet  c1500 suburban 2wd  2008
# 23     chevrolet            corvette  1999
# 24     chevrolet            corvette  1999
# 25     chevrolet            corvette  2008
# 26     chevrolet            corvette  2008
# 27     chevrolet            corvette  2008
# 28     chevrolet     k1500 tahoe 4wd  2008
# 29     chevrolet     k1500 tahoe 4wd  2008
# ..           ...                 ...   ...
# 204       toyota   toyota tacoma 4wd  1999
# 205       toyota   toyota tacoma 4wd  2008
# 206       toyota   toyota tacoma 4wd  2008
# 207   volkswagen                 gti  1999
# 208   volkswagen                 gti  1999
# 209   volkswagen                 gti  2008
# 210   volkswagen                 gti  2008
# 211   volkswagen                 gti  1999
# 212   volkswagen               jetta  1999
# 213   volkswagen               jetta  1999
# 214   volkswagen               jetta  1999
# 215   volkswagen               jetta  2008
# 216   volkswagen               jetta  2008
# 217   volkswagen               jetta  2008
# 218   volkswagen               jetta  2008
# 219   volkswagen               jetta  1999
# 220   volkswagen               jetta  1999
# 221   volkswagen          new beetle  1999
# 222   volkswagen          new beetle  1999
# 223   volkswagen          new beetle  1999
# 224   volkswagen          new beetle  1999
# 225   volkswagen          new beetle  2008
# 226   volkswagen          new beetle  2008
# 227   volkswagen              passat  1999
# 228   volkswagen              passat  1999
# 229   volkswagen              passat  2008
# 230   volkswagen              passat  2008
# 231   volkswagen              passat  1999
# 232   volkswagen              passat  1999
# 233   volkswagen              passat  2008
#
# [234 rows x 3 columns]

# %% [markdown]
# ## (c)

# %%
df.iloc[[9,19,29,34]]
# Out:
#    manufacturer               model  displ  year  cyl       trans drv  cty  \
# 9          audi          a4 quattro    2.0  2008    4  manual(m6)   4   20
# 19    chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 29    chevrolet     k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   11
# 34    chevrolet              malibu    3.1  1999    6    auto(l4)   f   18
#
#     hwy fl    class  new_col
# 9    28  p  compact     56.0
# 19   15  e      suv     79.5
# 29   14  e      suv     74.2
# 34   26  r  midsize     80.6

# %% [markdown]
# ## (d)

# %%
df[['manufacturer','year','class']].iloc[[99,199]]
# Out:
#     manufacturer  year       class
# 99         honda  1999  subcompact
# 199       toyota  2008         suv

# %% [markdown]
# ## (e)

# %%
df['manufacturer'].unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %% [markdown]
# ### Assignment 4.3
# #### (a) Find the maximum size of engine
# #### (b) Find the minimum mile per gallon in city across all cars
# #### (c) Find the average mile per gallon on highway across all cars
# #### (d) Create a new column in dataframe to normalize the mile per gallon on highway. You need to multiply mile per gallon on highway by engine size

# %% [markdown]
# ## (a)

# %%
df['displ'].max()
# Out:
# 7.0

# %% [markdown]
# ## (b)

# %%
df['cty'].min()
# Out:
# 9

# %% [markdown]
# ## (c)

# %%
df['hwy'].mean()
# Out:
# 23.44017094017094

# %% [markdown]
# ## (d)

# %%
df['new_col']=df['hwy']*df['displ']
df['new_col']
# Out:
# 0       52.2
# 1       52.2
# 2       62.0
# 3       60.0
# 4       72.8
# 5       72.8
# 6       83.7
# 7       46.8
# 8       45.0
# 9       56.0
# 10      54.0
# 11      70.0
# 12      70.0
# 13      77.5
# 14      77.5
# 15      67.2
# 16      77.5
# 17      96.6
# 18     106.0
# 19      79.5
# 20     106.0
# 21      96.9
# 22     102.0
# 23     148.2
# 24     131.1
# 25     161.2
# 26     155.0
# 27     168.0
# 28     100.7
# 29      74.2
#        ...
# 204     64.6
# 205     72.0
# 206     80.0
# 207     58.0
# 208     52.0
# 209     58.0
# 210     58.0
# 211     67.2
# 212     83.6
# 213     58.0
# 214     52.0
# 215     58.0
# 216     58.0
# 217     72.5
# 218     72.5
# 219     64.4
# 220     67.2
# 221     83.6
# 222     77.9
# 223     58.0
# 224     52.0
# 225     70.0
# 226     72.5
# 227     52.2
# 228     52.2
# 229     56.0
# 230     58.0
# 231     72.8
# 232     72.8
# 233     93.6
# Name: new_col, Length: 234, dtype: float64

# %% [markdown]
# ### Assignment 4.4
# #### (a) Find cars that have either 4 or 9 cylinders
# #### (b) Find cars that have engine size between 4 and 5 (inclusive, you need to include 4 and 5)
# #### (c) Find all suv cars manufactured by chevrolet except in 2008
# #### (d) What is average mile per gallon on highway for all models of toyota 4runner manufactured in 1999?

# %% [markdown]
# ## (a)

# %%
filter_cyl=(df['cyl']==4) | (df['cyl']==9)
df[filter_cyl]
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 0           audi                 a4    1.8  1999    4    auto(l5)   f   18
# 1           audi                 a4    1.8  1999    4  manual(m5)   f   21
# 2           audi                 a4    2.0  2008    4  manual(m6)   f   20
# 3           audi                 a4    2.0  2008    4    auto(av)   f   21
# 7           audi         a4 quattro    1.8  1999    4  manual(m5)   4   18
# 8           audi         a4 quattro    1.8  1999    4    auto(l5)   4   16
# 9           audi         a4 quattro    2.0  2008    4  manual(m6)   4   20
# 10          audi         a4 quattro    2.0  2008    4    auto(s6)   4   19
# 32     chevrolet             malibu    2.4  1999    4    auto(l4)   f   19
# 33     chevrolet             malibu    2.4  2008    4    auto(l4)   f   22
# 37         dodge        caravan 2wd    2.4  1999    4    auto(l3)   f   18
# 99         honda              civic    1.6  1999    4  manual(m5)   f   28
# 100        honda              civic    1.6  1999    4    auto(l4)   f   24
# 101        honda              civic    1.6  1999    4  manual(m5)   f   25
# 102        honda              civic    1.6  1999    4  manual(m5)   f   23
# 103        honda              civic    1.6  1999    4    auto(l4)   f   24
# 104        honda              civic    1.8  2008    4  manual(m5)   f   26
# 105        honda              civic    1.8  2008    4    auto(l5)   f   25
# 106        honda              civic    1.8  2008    4    auto(l5)   f   24
# 107        honda              civic    2.0  2008    4  manual(m6)   f   21
# 108      hyundai             sonata    2.4  1999    4    auto(l4)   f   18
# 109      hyundai             sonata    2.4  1999    4  manual(m5)   f   18
# 110      hyundai             sonata    2.4  2008    4    auto(l4)   f   21
# 111      hyundai             sonata    2.4  2008    4  manual(m5)   f   21
# 115      hyundai            tiburon    2.0  1999    4    auto(l4)   f   19
# 116      hyundai            tiburon    2.0  1999    4  manual(m5)   f   19
# 117      hyundai            tiburon    2.0  2008    4  manual(m5)   f   20
# 118      hyundai            tiburon    2.0  2008    4    auto(l4)   f   20
# 141       nissan             altima    2.4  1999    4  manual(m5)   f   21
# 142       nissan             altima    2.4  1999    4    auto(l4)   f   19
# ..           ...                ...    ...   ...  ...         ...  ..  ...
# 182       toyota              camry    2.4  2008    4    auto(l5)   f   21
# 186       toyota       camry solara    2.2  1999    4    auto(l4)   f   21
# 187       toyota       camry solara    2.2  1999    4  manual(m5)   f   21
# 188       toyota       camry solara    2.4  2008    4  manual(m5)   f   21
# 189       toyota       camry solara    2.4  2008    4    auto(s5)   f   22
# 193       toyota            corolla    1.8  1999    4    auto(l3)   f   24
# 194       toyota            corolla    1.8  1999    4    auto(l4)   f   24
# 195       toyota            corolla    1.8  1999    4  manual(m5)   f   26
# 196       toyota            corolla    1.8  2008    4  manual(m5)   f   28
# 197       toyota            corolla    1.8  2008    4    auto(l4)   f   26
# 200       toyota  toyota tacoma 4wd    2.7  1999    4  manual(m5)   4   15
# 201       toyota  toyota tacoma 4wd    2.7  1999    4    auto(l4)   4   16
# 202       toyota  toyota tacoma 4wd    2.7  2008    4  manual(m5)   4   17
# 207   volkswagen                gti    2.0  1999    4  manual(m5)   f   21
# 208   volkswagen                gti    2.0  1999    4    auto(l4)   f   19
# 209   volkswagen                gti    2.0  2008    4  manual(m6)   f   21
# 210   volkswagen                gti    2.0  2008    4    auto(s6)   f   22
# 212   volkswagen              jetta    1.9  1999    4  manual(m5)   f   33
# 213   volkswagen              jetta    2.0  1999    4  manual(m5)   f   21
# 214   volkswagen              jetta    2.0  1999    4    auto(l4)   f   19
# 215   volkswagen              jetta    2.0  2008    4    auto(s6)   f   22
# 216   volkswagen              jetta    2.0  2008    4  manual(m6)   f   21
# 221   volkswagen         new beetle    1.9  1999    4  manual(m5)   f   35
# 222   volkswagen         new beetle    1.9  1999    4    auto(l4)   f   29
# 223   volkswagen         new beetle    2.0  1999    4  manual(m5)   f   21
# 224   volkswagen         new beetle    2.0  1999    4    auto(l4)   f   19
# 227   volkswagen             passat    1.8  1999    4  manual(m5)   f   21
# 228   volkswagen             passat    1.8  1999    4    auto(l5)   f   18
# 229   volkswagen             passat    2.0  2008    4    auto(s6)   f   19
# 230   volkswagen             passat    2.0  2008    4  manual(m6)   f   21
#
#      hwy fl       class  new_col
# 0     29  p     compact     52.2
# 1     29  p     compact     52.2
# 2     31  p     compact     62.0
# 3     30  p     compact     60.0
# 7     26  p     compact     46.8
# 8     25  p     compact     45.0
# 9     28  p     compact     56.0
# 10    27  p     compact     54.0
# 32    27  r     midsize     64.8
# 33    30  r     midsize     72.0
# 37    24  r     minivan     57.6
# 99    33  r  subcompact     52.8
# 100   32  r  subcompact     51.2
# 101   32  r  subcompact     51.2
# 102   29  p  subcompact     46.4
# 103   32  r  subcompact     51.2
# 104   34  r  subcompact     61.2
# 105   36  r  subcompact     64.8
# 106   36  c  subcompact     64.8
# 107   29  p  subcompact     58.0
# 108   26  r     midsize     62.4
# 109   27  r     midsize     64.8
# 110   30  r     midsize     72.0
# 111   31  r     midsize     74.4
# 115   26  r  subcompact     52.0
# 116   29  r  subcompact     58.0
# 117   28  r  subcompact     56.0
# 118   27  r  subcompact     54.0
# 141   29  r     compact     69.6
# 142   27  r     compact     64.8
# ..   ... ..         ...      ...
# 182   31  r     midsize     74.4
# 186   27  r     compact     59.4
# 187   29  r     compact     63.8
# 188   31  r     compact     74.4
# 189   31  r     compact     74.4
# 193   30  r     compact     54.0
# 194   33  r     compact     59.4
# 195   35  r     compact     63.0
# 196   37  r     compact     66.6
# 197   35  r     compact     63.0
# 200   20  r      pickup     54.0
# 201   20  r      pickup     54.0
# 202   22  r      pickup     59.4
# 207   29  r     compact     58.0
# 208   26  r     compact     52.0
# 209   29  p     compact     58.0
# 210   29  p     compact     58.0
# 212   44  d     compact     83.6
# 213   29  r     compact     58.0
# 214   26  r     compact     52.0
# 215   29  p     compact     58.0
# 216   29  p     compact     58.0
# 221   44  d  subcompact     83.6
# 222   41  d  subcompact     77.9
# 223   29  r  subcompact     58.0
# 224   26  r  subcompact     52.0
# 227   29  p     midsize     52.2
# 228   29  p     midsize     52.2
# 229   28  p     midsize     56.0
# 230   29  p     midsize     58.0
#
# [81 rows x 12 columns]

# %% [markdown]
# ## (b)

# %%
filter_displ=(df['displ']>=4) & (df['displ']<=5)
df[filter_displ]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 17          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 47         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 52         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 58         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 59         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 64         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 65         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 74          ford          expedition 2wd    4.6  1999    8    auto(l4)   r
# 77          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 78          ford            explorer 4wd    4.0  1999    6  manual(m5)   4
# 79          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 80          ford            explorer 4wd    4.0  2008    6    auto(l5)   4
# 81          ford            explorer 4wd    4.6  2008    8    auto(l6)   4
# 82          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 83          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6  manual(m5)   4
# 85          ford         f150 pickup 4wd    4.6  1999    8  manual(m5)   4
# 86          ford         f150 pickup 4wd    4.6  1999    8    auto(l4)   4
# 87          ford         f150 pickup 4wd    4.6  2008    8    auto(l4)   4
# 92          ford                 mustang    4.0  2008    6  manual(m5)   r
# 93          ford                 mustang    4.0  2008    6    auto(l5)   r
# 94          ford                 mustang    4.6  1999    8    auto(l4)   r
# 95          ford                 mustang    4.6  1999    8  manual(m5)   r
# 96          ford                 mustang    4.6  2008    8  manual(m5)   r
# 97          ford                 mustang    4.6  2008    8    auto(l5)   r
# 124         jeep      grand cherokee 4wd    4.0  1999    6    auto(l4)   4
# 125         jeep      grand cherokee 4wd    4.7  1999    8    auto(l4)   4
# 126         jeep      grand cherokee 4wd    4.7  2008    8    auto(l5)   4
# 127         jeep      grand cherokee 4wd    4.7  2008    8    auto(l5)   4
# 130   land rover             range rover    4.0  1999    8    auto(l4)   4
# 131   land rover             range rover    4.2  2008    8    auto(s6)   4
# 132   land rover             range rover    4.4  2008    8    auto(s6)   4
# 133   land rover             range rover    4.6  1999    8    auto(l4)   4
# 137      mercury         mountaineer 4wd    4.0  1999    6    auto(l5)   4
# 138      mercury         mountaineer 4wd    4.0  2008    6    auto(l5)   4
# 139      mercury         mountaineer 4wd    4.6  2008    8    auto(l6)   4
# 140      mercury         mountaineer 4wd    5.0  1999    8    auto(l4)   4
# 152       nissan          pathfinder 4wd    4.0  2008    6    auto(l5)   4
# 177       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 178       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 198       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 205       toyota       toyota tacoma 4wd    4.0  2008    6  manual(m6)   4
# 206       toyota       toyota tacoma 4wd    4.0  2008    6    auto(l5)   4
#
#      cty  hwy fl       class  new_col
# 17    16   23  p     midsize     96.6
# 47    16   23  r     minivan     92.0
# 52    14   19  r      pickup     89.3
# 53    14   19  r      pickup     89.3
# 54     9   12  e      pickup     56.4
# 58    13   17  r         suv     79.9
# 59     9   12  e         suv     56.4
# 60    13   17  r         suv     79.9
# 64    12   16  r      pickup     75.2
# 65     9   12  e      pickup     56.4
# 66    13   17  r      pickup     79.9
# 67    13   17  r      pickup     79.9
# 68    12   16  r      pickup     75.2
# 69     9   12  e      pickup     56.4
# 74    11   17  r         suv     78.2
# 77    14   17  r         suv     68.0
# 78    15   19  r         suv     76.0
# 79    14   17  r         suv     68.0
# 80    13   19  r         suv     76.0
# 81    13   19  r         suv     87.4
# 82    13   17  r         suv     85.0
# 83    14   17  r      pickup     71.4
# 84    14   17  r      pickup     71.4
# 85    13   16  r      pickup     73.6
# 86    13   16  r      pickup     73.6
# 87    13   17  r      pickup     78.2
# 92    17   26  r  subcompact    104.0
# 93    16   24  r  subcompact     96.0
# 94    15   21  r  subcompact     96.6
# 95    15   22  r  subcompact    101.2
# 96    15   23  r  subcompact    105.8
# 97    15   22  r  subcompact    101.2
# 124   15   20  r         suv     80.0
# 125   14   17  r         suv     79.9
# 126    9   12  e         suv     56.4
# 127   14   19  r         suv     89.3
# 130   11   15  p         suv     60.0
# 131   12   18  r         suv     75.6
# 132   12   18  r         suv     79.2
# 133   11   15  p         suv     69.0
# 137   14   17  r         suv     68.0
# 138   13   19  r         suv     76.0
# 139   13   19  r         suv     87.4
# 140   13   17  r         suv     85.0
# 152   14   20  p         suv     80.0
# 177   16   20  r         suv     80.0
# 178   14   17  r         suv     79.9
# 198   11   15  r         suv     70.5
# 205   15   18  r      pickup     72.0
# 206   16   20  r      pickup     80.0

# %% [markdown]
# ## (c)

# %%
filter_suv=(df['class']=='suv') & (df['manufacturer']=='chevrolet') & (df['year']!=2008)
df[filter_suv]
# Out:
#    manufacturer               model  displ  year  cyl     trans drv  cty  hwy  \
# 21    chevrolet  c1500 suburban 2wd    5.7  1999    8  auto(l4)   r   13   17
# 30    chevrolet     k1500 tahoe 4wd    5.7  1999    8  auto(l4)   4   11   15
# 31    chevrolet     k1500 tahoe 4wd    6.5  1999    8  auto(l4)   4   14   17
#
#    fl class  new_col
# 21  r   suv     96.9
# 30  r   suv     85.5
# 31  d   suv    110.5

# %% [markdown]
# ## (d)

# %%
filter_toyota=(df['model'].str.contains('4runner')) & (df['manufacturer']=='toyota') & (df['year']==1999)
df[filter_toyota]['hwy'].mean()
# Out:
# 19.0
