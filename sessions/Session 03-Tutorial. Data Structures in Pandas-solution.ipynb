# %% [markdown]
# # Session 03 - Tutorial. Data Structures in Pandas

# %% [markdown]
# **Remember, to save jupyter-notebook on Binder, you need to download and upload the file**
#
# **If you leave Binder for a while you may lose your connection!**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## 1. Load a dataset

# %% [markdown]
# - Use this link to load the dataset https://raw.githubusercontent.com/mosleh-exeter/BEM1025/main/Fun%2C%20beginner-friendly%20datasets/museums.csv
#  read more here: https://www.kaggle.com/imls/museum-directory

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mosleh-exeter/BEM1025/main/Fun%2C%20beginner-friendly%20datasets/museums.csv")
# Out:
# /Users/mm1049/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3418: DtypeWarning: Columns (9,14,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## 2. Structure of the dataset

# %% [markdown]
# - how many rows and columns in the dataset?

# %%
print('rows: {}, columns: {}'.format(df.shape[0],df.shape[1]))
# Out:
# rows: 33072, columns: 25

# %% [markdown]
# - What is the type of each column variables?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33072 entries, 0 to 33071
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Museum ID                                 33072 non-null  int64
#  1   Museum Name                               33072 non-null  object
#  2   Legal Name                                33072 non-null  object
#  3   Alternate Name                            1927 non-null   object
#  4   Museum Type                               33072 non-null  object
#  5   Institution Name                          2749 non-null   object
#  6   Street Address (Administrative Location)  33062 non-null  object
#  7   City (Administrative Location)            33072 non-null  object
#  8   State (Administrative Location)           33072 non-null  object
#  9   Zip Code (Administrative Location)        33072 non-null  object
# ...

# %% [markdown]
# ## 3. Columns and row extraction

# %% [markdown]
# - Create a new dataframe that has only the following columns : 'Museum ID', 'Museum Name', 'Legal Name','Museum Type', 'Institution Name'

# %%
col_select=[ 'Museum ID', 'Museum Name', 'Legal Name','Museum Type', 'Institution Name']
df1=df[col_select]

# %% [markdown]
# - Create a new dataframe that has only the following rows : 10, 200,400,

# %%
rows_select=[10, 200,400]
df2=df.iloc[rows_select]

# %% [markdown]
# - Create a new dataframe that has the following columns 'Museum ID', 'Museum Name' and the following rows 100-200, 300-500

# %%
rows_select=list(range(100,200))+list(range(300,500))
col_select=['Museum ID', 'Museum Name']
df3=df.iloc[rows_select][col_select]

# %% [markdown]
# - Show the last 1000 rows

# %%
df.tail(1000)
# Out:
#         Museum ID                                    Museum Name  \
# 32072  8405500192                     HERITAGE OF PORTAGE COUNTY
# 32073  8405500845                    HIGHLAND HISTORICAL SOCIETY
# 32074  8405500255                       HISTORIC ALLOUEZ SOCIETY
# 32075  8405500704                                HISTORIC ARGYLE
# 32076  8405500221     HISTORIC BLOOMING GROVE HISTORICAL SOCIETY
# ...           ...                                            ...
# 33067  8405600184               WYOMING STATE HISTORICAL SOCIETY
# 33068  8405600061                           WYOMING STATE MUSEUM
# 33069  8405600158  WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33070  8405600137                  WYOMING TRANSPORTATION MUSEUM
# 33071  8405600199                      YELLOWSTONE NATIONAL PARK
#
#                                               Legal Name Alternate Name  \
# 32072                     HERITAGE OF PORTAGE COUNTY INC            NaN
# ...

# %%
df.iloc[df.shape[0]-1000:]
# Out:
#         Museum ID                                    Museum Name  \
# 32072  8405500192                     HERITAGE OF PORTAGE COUNTY
# 32073  8405500845                    HIGHLAND HISTORICAL SOCIETY
# 32074  8405500255                       HISTORIC ALLOUEZ SOCIETY
# 32075  8405500704                                HISTORIC ARGYLE
# 32076  8405500221     HISTORIC BLOOMING GROVE HISTORICAL SOCIETY
# ...           ...                                            ...
# 33067  8405600184               WYOMING STATE HISTORICAL SOCIETY
# 33068  8405600061                           WYOMING STATE MUSEUM
# 33069  8405600158  WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33070  8405600137                  WYOMING TRANSPORTATION MUSEUM
# 33071  8405600199                      YELLOWSTONE NATIONAL PARK
#
#                                               Legal Name Alternate Name  \
# 32072                     HERITAGE OF PORTAGE COUNTY INC            NaN
# ...

# %% [markdown]
# - Extract your results as pdf!
